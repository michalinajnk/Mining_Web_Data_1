# %% [markdown]
# <a href="https://colab.research.google.com/github/michalinajnk/Mining_Web_Data_1/blob/main/BT4222_Google_Maps_Places_APIs_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Google Maps Platform - Places API Exploration
#
# This notebook explores the usage of the Google Maps Platform - Places API, using the retrieval of restaurant reviews as an example.
#
# **Google Maps Platform Places API Overview** - https://developers.google.com/maps/documentation/places/web-service/overview
#
# Version:
# - Revised by Shi Yingfei shi_yingfei@u.nus.edu in January 2024.
# - Revised by Wang Qiuhong in August 2024.

# %% [markdown]
# ### Import Packages Needed

# %%
import requests
import json
import time
import pandas as pd

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# List of MRT stations for test purpose
test_mrt_stations = ["Toa Payoh", "Clementi", "Ang Mo Kio"]

# %%
# Test search queries for restaurants near the MRT stations
res_search_query = "restaurants in {}"
test_search_queries = [res_search_query.format(mrt) for mrt in test_mrt_stations]

print(test_search_queries)
# Out:
# ['restaurants in Toa Payoh', 'restaurants in Clementi', 'restaurants in Ang Mo Kio']

# %% [markdown]
# ### Generate API key
#
# You may reference the **How to use the Places API** section through this link: https://developers.google.com/maps/documentation/places/web-service/overview#how-to-use-the-places-api

# %%
API_KEY = 'AIzaSyDBSZKpjVDAAPjFQlmXEH5BCzoN2TeAMEY'# Replace with your own API_KEY

# %% [markdown]
# ### Text Search
#
# **Text Search documentation** - https://developers.google.com/maps/documentation/places/web-service/search-text

# %%
def call_text_search_api(query, next_page_token=None, api_key=None):
    """Makes an API call to the Google Places API.

    Args:
        query (str): The search query to pass to the Google Places API.
        next_page_token (str): Token for the next page of results, if available.
        api_key (str): Your Google Places API key.

    Returns:
        A tuple containing a list of place IDs from the API and the next page token, if available.
    """
    # Construct the API request URL with the provided query and API key
    url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={query}&key={api_key}"

    # If a next_page_token is provided, append it to the URL
    if next_page_token:
        url += f"&pagetoken={next_page_token}"

    # Make the API request using the constructed URL
    response = requests.get(url)

    # Check if the API request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        data = json.loads(response.content)

        # Check if the "results" key is present in the response data
        if "results" in data:
            # Extract place IDs from the results
            place_ids = [item["place_id"] for item in data["results"]]
        else:
            # Set place_ids to an empty list if no results are present
            place_ids = []

        # Extract the next page token, if available
        next_token = data.get("next_page_token", None)

        # Return the place IDs and next page token as a tuple
        return place_ids, next_token
    else:
        # Raise an exception if the API call fails
        raise Exception(f"Failed to make API call. Status code: {response.status_code}")

# %%
# Retrieve all place IDs based on the test search queries
all_place_ids = []

# Iterate through each search query
for query in test_search_queries:
    next_token = None

    # Continue fetching results until there is no next page token
    while True:
        # Make Text Search API call to get place IDs and the next page token
        place_ids, next_token = call_text_search_api(query, next_token, API_KEY)

        # Extend the list of place IDs with the retrieved ones
        all_place_ids.extend(place_ids)


        # If no next page token, break the loop
        if not next_token:
            break

        # Introduce a delay of 2 seconds between API calls (Google API's multi-page pacing requirements)
        time.sleep(2)

# Remove duplicates from the list of all place IDs
unique_place_ids = list(set(all_place_ids))

# Print several unique place IDs and total count
print(unique_place_ids[:10])
print(f"Number of unique place IDs: {len(unique_place_ids)}")
# Out:
# ['ChIJz86GbZka2jERAFWm-I-74wU', 'ChIJx5tHAHwX2jERZuVzoos-cGQ', 'ChIJPRf_WwAb2jERa-Q8bxSZzJk', 'ChIJ410Ar3oX2jERATqJiwgW658', 'ChIJef0GcZUX2jERAArkEu6jCiU', 'ChIJl--U8-QX2jERgySBbJ44Zq0', 'ChIJ9y7Rbo4a2jERLC1BGHJVV_w', 'ChIJ4aryd_oX2jER8wW0zUiUhPk', 'ChIJa9-WMuYW2jERpX9iQ7SEmws', 'ChIJYZ3qqZ8b2jER456-75ycqgw']
# Number of unique place IDs: 180

# %% [markdown]
# ### Place Details
#
# **Place Details documentation** - https://developers.google.com/maps/documentation/places/web-service/details

# %%
def call_place_api(url):
    """
    Makes an API call to the Google Places API.

    Args:
        url (str): The URL of the API endpoint.

    Returns:
        dict: A dictionary containing the JSON response from the API.
    """
    try:
        # Make a GET request to the specified URL
        response = requests.get(url)

        # Check if the response status code is 200 (OK)
        if response.status_code == 200:
            # Parse the JSON content of the response
            api_response = json.loads(response.content)
            return api_response
        else:
            # Raise an exception if the API call fails
            raise Exception(f"Failed to make API call. Status code: {response.status_code}")

    except Exception as e:
        # Handle and raise any exceptions that may occur during the API call
        raise Exception(f"An error occurred during the API call: {str(e)}")

# %%
def get_reviews(place_ids, api_key):
    """Retrieve reviews for a list of place IDs using the Google Places API.

    Args:
        place_ids (list): A list of place IDs.
        api_key (str): Your Google API key.

    Returns:
        dict: A dictionary where keys are place IDs and values are lists of reviews for each place.
    """

    all_reviews = {}

    for place_id in place_ids:
        # Construct the URL for Place Details API call
        url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&key={api_key}"

        # Make the API call to get place details
        response = call_place_api(url)

        # Check if the response contains reviews
        if "result" in response and "reviews" in response["result"]:
            # Extract reviews and store them in the dictionary
            reviews = response["result"]["reviews"]
            all_reviews[place_id] = [{"rating": review["rating"], "text": review.get("text", "")} for review in reviews]
        else:
            # If no reviews are found, store an empty list
            all_reviews[place_id] = []

    return all_reviews

# %%
# Get reviews for all unique place IDs
reviews_dict = get_reviews(unique_place_ids, API_KEY)

# %%
# Check the list of reviews of one place_id
for place_id, reviews in reviews_dict.items():
  print(f"Reviews for Place ID: {place_id}")
  for review in reviews:
    print(review,'/n')

  break
# Out:
# Reviews for Place ID: ChIJz86GbZka2jERAFWm-I-74wU
# {'rating': 5, 'text': 'Very quaint and cosy place hidden in the neighbourhood. Decoration of the restaurant gives a very warm and welcoming vibe. Staff’s service is good too, frequently checking on our needs and quality of food. Food serving size is big for the prices. Do pre-order Mummy’s Curry Chicken in case out of stock! Honey Mustard Wings is a must order. Crispy Fish & Fries is very nicely done and not oily. A good place for family and friends.'} /n
# {'rating': 4, 'text': 'Quaint and charming western restaurant located in the quiet Faber neighbourhood.\n\nFood was unpretentious and earnestly prepared! Fish and chips was really solid; pumpkin soup was tasty and the kids meal and a bit of everything. The steak was a tad unevenly and under cooked, which was a waste. But we will certainly be back to try the rest of the menu.\n\nLoved the kids corner which had plenty of toys and books to entertain the little ones.\n\nPrice is slightly on the high side but not more than your standard western food chains. Do give them a shot!'} /n
# {'rating': 4, 'text': 'Hidden inside Faber Garden. Easy to find parking. Decorated with caryon Shin Chan character. We are able to find a table on a Friday evening. The place is busy. The food took a while to be served. The food taste good.'} /n
# {'rating': 4, 'text': 'Had grandma curry chicken paired w fluffy bread, very tender lamb shank and mushroom baked cheese rice. The standard is there. Together w cosy setting, this is def homely meals that one could enjoy any day.'} /n
# {'rating': 5, 'text': 'Love this place and have been a patron for the past few years. This place has offered sanctuary and respite from the busy hectic Singapore pace of life. The music immediately calms your senses and you feel time slow down. A wide selection of drinks gives everyone something to enjoy and chill over (alcoholic, caffeinated, or just sweet delights.. they have them all!)\n\nMore importantly, they also have an awesome selection of food, all of which are delicious and value for money. Their servings are larger than what you’ll typically expect from Singapore F&B outlets, so if you’re a small eater, bring a partner to share!\n\nMy first post of this place I think, but will gladly post more reviews the next time I visit! ❤️'} /n

# %% [markdown]
# ### Save Data

# %%
# Save reviews_dict as a JSON file
with open('/content/drive/MyDrive/temp/test_reviews.json', 'w') as file:
    json.dump(reviews_dict, file)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the JSON file
with open('/content/drive/MyDrive/temp/test_reviews.json', 'r') as file:
  data = json.load(file)

# %%
# Flatten reviews data created from a nested dictionary (data) to a list of dictionaries
flattened_data = []

for place_id, reviews in data.items():
  for review in reviews:
        # Add the place_id to each review
        review['place_id'] = place_id
        flattened_data.append(review)

# Create a Pandas DataFrame from the flattened data
scraped_data = pd.DataFrame(flattened_data)

# Check the resulting DataFrame
print(scraped_data.shape)
scraped_data.head()
# Out:
# (895, 3)
#    rating                                               text  \
# 0       5  Very quaint and cosy place hidden in the neigh...
# 1       4  Quaint and charming western restaurant located...
# 2       4  Hidden inside Faber Garden. Easy to find parki...
# 3       4  Had grandma curry chicken paired w fluffy brea...
# 4       5  Love this place and have been a patron for the...
#
#                       place_id
# 0  ChIJz86GbZka2jERAFWm-I-74wU
# 1  ChIJz86GbZka2jERAFWm-I-74wU
# 2  ChIJz86GbZka2jERAFWm-I-74wU
# 3  ChIJz86GbZka2jERAFWm-I-74wU
# 4  ChIJz86GbZka2jERAFWm-I-74wU

# %%
# Store the scraped data into a csv file
scraped_data.to_csv("/content/drive/MyDrive/temp/test_scraped_review.csv", index = False)

# %%
# Check the scraped review of one place id
### [Note] Based on the Place Details documentation, the reviews contain a JSON array of up to five reviews only.
# Place - reviews:
# A JSON array of up to five reviews. By default, the reviews are sorted in order of relevance. Use the reviews_sort
# request parameter to control sorting.
# For most_relevant (default), reviews are sorted by relevance; the service will bias the results to return reviews
# originally written in the preferred language.
# For newest, reviews are sorted in chronological order; the preferred language does not affect the sort order.
# Google recommends indicating to users whether results are ordered by most_relevant or newest.

scraped_data.loc[scraped_data.place_id == unique_place_ids[0]]
# Out:
#    rating                                               text  \
# 0       5  Very quaint and cosy place hidden in the neigh...
# 1       4  Quaint and charming western restaurant located...
# 2       4  Hidden inside Faber Garden. Easy to find parki...
# 3       4  Had grandma curry chicken paired w fluffy brea...
# 4       5  Love this place and have been a patron for the...
#
#                       place_id
# 0  ChIJz86GbZka2jERAFWm-I-74wU
# 1  ChIJz86GbZka2jERAFWm-I-74wU
# 2  ChIJz86GbZka2jERAFWm-I-74wU
# 3  ChIJz86GbZka2jERAFWm-I-74wU
# 4  ChIJz86GbZka2jERAFWm-I-74wU

# %% [markdown]
# # Questions for you
# 1.Could you extract “name” for each place ID and include it into the json file?
#
# 2.What is the limitation of Google Maps Places API for review retrieval? Is there any legitimate solution to avoid such a limitation?
#
# ## How to submit?
#
# 1.Download the example source code from the files folder on Canvas.
# 2.For programming tasks, revise the original scripts or insert yours to complete the task, with markdown to highlight the changes you made or the scripts you inserted. Show and keep your output as evidences.
# 3.For short-answer questions, provide your answer at the end of the example notebook file.
# 4.If you want to contribute something else, elaborate it and justify your contribution at the end of the example notebook file.
# 5.Submit your source code via the corresponding assignment on Canvas.

# %% [markdown]
# # Your answer

# %% [markdown]
# 1.Yes, I could  extract “name” for each place ID and include it into the json file. Below I am attaching a code which append a name to json file as well as to csv file.

# %%
def get_name(place_ids, api_key):
    """Retrieve name for a list of place IDs using the Google Places API.

    Args:
        name (list): A list of place IDs.
        api_key (str): Your Google API key.

    Returns:
        dict: A dictionary where keys are place IDs and value is a name for each place.
    """

    all_names = {}

    for place_id in place_ids:
        # Construct the URL for Place Details API call
        url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&key={api_key}"

        # Make the API call to get place details
        response = call_place_api(url)

        # Check if the response contains reviews
        if "result" in response and "name" in response["result"]:
            # Extract reviews and store them in the dictionary
            name = response["result"]["name"]
            all_names[place_id] = name
        else:
            # If no reviews are found, store an empty list
            all_names[place_id] = "NA"

    return all_names

# %%
names_dict = get_name(unique_place_ids, API_KEY)
df = pd.DataFrame(scraped_data)

# %%
# Iterate over the DataFrame rows
for index, row in df.iterrows():
    place_id = row["place_id"]
    df.at[index, "name"] = names_dict.get(place_id, "NA")

# Store the DataFrame into a CSV file
df.to_csv("/content/drive/MyDrive/temp/test_scraped_review.csv", index=False)

# %%
def get_reviews_with_names(place_ids, api_key):
    """Retrieve reviews and names for a list of place IDs using the Google Places API.

    Args:
        place_ids (list): A list of place IDs.
        api_key (str): Your Google API key.

    Returns:
        list: A list of dictionaries containing place_id, name, and reviews.
    """
    all_data = {}
    all_reviews = {}

    for place_id in place_ids:
        # Construct the URL for Place Details API call
        url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&key={api_key}"

        # Make the API call to get place details
        response = call_place_api(url)

        # Check if the response contains the place name
        if "result" in response and "name" in response["result"]:
            # Extract name and store it in the dictionary
            name = response["result"]["name"]
            all_data[place_id] = name
        else:
            # If no name is found, store an empty string
            all_data[place_id] = ""

        # Check if the response contains reviews
        if "result" in response and "reviews" in response["result"]:
            # Extract reviews and store them in the dictionary
            reviews = response["result"]["reviews"]
            all_reviews[place_id] = [{"rating": review["rating"], "text": review.get("text", "")} for review in reviews]
        else:
            # If no reviews are found, store an empty list
            all_reviews[place_id] = []

    # Perform a "left join" between all_data and all_reviews
    combined_data = []
    for place_id in all_data:
        combined_entry = {
            "place_id": place_id,
            "name": all_data[place_id],
            "reviews": all_reviews.get(place_id, [])
        }
        combined_data.append(combined_entry)

    return combined_data

# %%
combined_data = get_reviews_with_names(unique_place_ids, API_KEY)

# Save reviews_dict as a JSON file
with open('/content/drive/MyDrive/temp/test_reviews.json', 'w') as file:
    json.dump(combined_data, file)

# Iterate over the combined data
for place in combined_data:
    print(f"Place ID: {place['place_id']}")
    print(f"Name: {place['name']}")

    # Check if there are reviewsA
    if place['reviews']:
        print("Reviews:")
        for review in place['reviews']:
            print(f"  Rating: {review['rating']}")
            print(f"  Review Text: {review['text']}")
    else:
        print("No reviews found.")

    print("-" * 40)  # Separator between places
# Out:
# Place ID: ChIJz86GbZka2jERAFWm-I-74wU
# Name: Jovis Cafe - The Dining Place
# Reviews:
#   Rating: 5
#   Review Text: Very quaint and cosy place hidden in the neighbourhood. Decoration of the restaurant gives a very warm and welcoming vibe. Staff’s service is good too, frequently checking on our needs and quality of food. Food serving size is big for the prices. Do pre-order Mummy’s Curry Chicken in case out of stock! Honey Mustard Wings is a must order. Crispy Fish & Fries is very nicely done and not oily. A good place for family and friends.
#   Rating: 4
#   Review Text: Quaint and charming western restaurant located in the quiet Faber neighbourhood.
#
# Food was unpretentious and earnestly prepared! Fish and chips was really solid; pumpkin soup was tasty and the kids meal and a bit of everything. The steak was a tad unevenly and under cooked, which was a waste. But we will certainly be back to try the rest of the menu.
#
# Loved the kids corner which had plenty of toys and books to entertain the little ones.
#
# Price is slightly on the high side but not more than your standard western food chains. Do give them a shot!
#   Rating: 4
#   Review Text: Hidden inside Faber Garden. Easy to find parking. Decorated with caryon Shin Chan character. We are able to find a table on a Friday evening. The place is busy. The food took a while to be served. The food taste good.
#   Rating: 4
#   Review Text: Had grandma curry chicken paired w fluffy bread, very tender lamb shank and mushroom baked cheese rice. The standard is there. Together w cosy setting, this is def homely meals that one could enjoy any day.
#   Rating: 5
#   Review Text: Love this place and have been a patron for the past few years. This place has offered sanctuary and respite from the busy hectic Singapore pace of life. The music immediately calms your senses and you feel time slow down. A wide selection of drinks gives everyone something to enjoy and chill over (alcoholic, caffeinated, or just sweet delights.. they have them all!)
#
# More importantly, they also have an awesome selection of food, all of which are delicious and value for money. Their servings are larger than what you’ll typically expect from Singapore F&B outlets, so if you’re a small eater, bring a partner to share!
#
# My first post of this place I think, but will gladly post more reviews the next time I visit! ❤️
# ----------------------------------------
# Place ID: ChIJx5tHAHwX2jERZuVzoos-cGQ
# Name: Master Chippy (Toa Payoh)
# Reviews:
#   Rating: 4
#   Review Text: The food was reasonably good. The baked rice was great. It might be better than cafe/restaurant standard. The grilled chicken chop was average but the fries are good. When we visited, it was a Sunday with no crowd, the place had a laid back vibe to it.
#   Rating: 3
#   Review Text: Master Chippy @ Toa Payoh N.
#
# Ordered the Sweetlip Fish and Chips with fries and mash. While the fish was fried really well, the quality of the fish was personally abit lacking. Felt abit old, some parts were slightly tough, kinda like it was frozen for awhile, but not too much. The Dory might fare better for your tastebuds and wallet. Still, overall cooked well as the fish was flaky and not crumbly
#
# The fries are normal, run of the mill frozen, it’s aight. The Mash though, was pretty good, nice rich gravy and creamy puree.
#
# The tartar sauce is prepackaged too, and not very tasty, get the chilli sauce.(I wonder if the mash was also prepackaged)
#
# For a store called Master Chippy, I was expecting a more specialized stall, this store’s menu was mind-boggling, serving even beef stew. As a result, for the variety it serves, it seems the quality became disappointing, considering what I expected from the name. Still alright though, if you don’t go fancy they don’t cost fancy either. Reduce the menu to focus on good parts and make better chips to fit the namesake maybe?
# 6/10
#   Rating: 2
#   Review Text: The 2nd best thing here was the mashed potato. The 1st was being able to use CDC voucher. Hence 2 stars.
#
# Ordered the halibut (which is my favourite go-to for fish and chips) and was disappointed. It was so pricey, a tad over fried, and pretty much tasteless. I probably would’ve been happier at LJS. We also tried the Snapper.. which was so hard and dry I almost thought it was a chicken breast.
#
# Wouldn’t recommend this place if you’re looking for good fish and chips and willing to pay more. But if you do decide to try this place, I hope your experience will be better than mine.
#   Rating: 5
#   Review Text: Truly amazing fish and chips for kopitiam standard
# i ordered their tilapia fish and chips maybe because is from freshwater it doesnt taste as salty as it is althought i have put quite amount of salt.
# Fries on point delicious.
# Coleslaw was fantastic.
# will come back to try their snapper, that day they ran out of stock.
# This place no pork no lard no alcohol.
#   Rating: 5
#   Review Text: In my opinion, this is the best fish and chips you can get under 10 bucks in Singapore. Had been patronising more than 10 years ago since they were at POMO and this is the Fish n Chips that's changed my perspective of the dish (even better than Bread Street's imo). Still so good after so many years. The balance of the thin crispy batter and thickness of the fish is perfect. For 7.90 you get 1 fish and 2 sides. Be sure to drizzle malt vinegar before every bite! High recommend the Dory Fish n Chips.
# ----------------------------------------
# Place ID: ChIJPRf_WwAb2jERa-Q8bxSZzJk
# Name: Qin Ji Rougamo
# Reviews:
#   Rating: 3
#   Review Text: 1st time trying, service was quite fast. Food was average only, ordered the minced pork in bean sauce and there are better minced pork noodles around clementi. Only the qinji pork bun was worth the try, bread was crispy and the meat was pretty good. Apart from that, not worth the price. Likely wont visit again.
#   Rating: 3
#   Review Text: I order a beef set which is a drink, noodles and the rou ga mo. I felt the price for the set is expensive for the quality of food i am getting.
#
# Out of the three items, its only the rou ga mo that stand out. Its crispy and have sufficient meat filling. The soya milk and noodles is very very average. Nothing to rave about. Service is fast. I will likely not order again.
#   Rating: 4
#   Review Text: It’s a new brand in clementi mall, they offers rougamo , liangpi , Hot and Sour Rice Noodles, and a couple of beverages.
# Actually these are really normal food in China and noway to have a such high price but since it’s Singapore 🇸🇬 I can understand but I don’t think it’s gone be a daily choice at least for me.
# We tried the liangpi and overall it is ok but flavor is not as powerful as I thought. Spiciness, sourness and garlic flavor are all sort of fewer than it should be. Maybe it changes the recipe for local.
# They use the disposable bowl which I think not very environmental friendly.
# 6.9 dollars but not full (60%full ) for a girl is really not a good choice.
#   Rating: 2
# Ambience was peaceful.
#   Rating: 3
#   Review Text: I had lunch here. Order a few dishes. The highlight was the steam chicken and the rest of the dishes were just average. The area where I was sitting was very warm and and stuffy. The place looks kinda "aged". The ceiling is mouldy.
# ----------------------------------------
# Place ID: ChIJ4aryd_oX2jER8wW0zUiUhPk
# Name: Monday Coffee Bar
# Reviews:
#   Rating: 3
#   Review Text: A nice cosy Japanese style cafe on the interior.
# The exterior of the cafe has a strong smell that lingers at the outdoor seating.
# No fan or air cooler at the outdoor seating.
#
# Coffee is good, but sandwiches kinda off its worth.
#
# It's likely to return just for takeaway.
#   Rating: 5
#   Review Text: My sister and I often eat here. Today I just ate late lunch: flatwhite and chicken katsu sandwich and was asked by a very nice lady staff "how was my coffee and sandwich". I've felt I didn't gave her enough feedbacks, so I have decided to write a review instead. We actually love the coffee shop very much, that is why we often visit this place, rather than other commercialized coffee shops nearby. The ambience is cozy, clean, the staffs are all nice and most importantly, the food and drinks are served and in good quality. As mentioned to the lady, I only wished they have a larger cup size of the drinks. But overall the place is really goood and instagramable 😊☕️✨
#   Rating: 4
#   Review Text: Stumbled upon this small and rather unique cafe that is located in the ang Mo kio neighbourhood. It is rather small with few seatings indoors and outdoors. But the ambience of this place is great.
#
# Their menu is simple but that is truly enough. We tried their luncheon tamogoyaki sando which was nice. Their late and hot chocolate was also good. And so were their Earl grey brownie which is small but just the right size.
#
# Really cosy cafe and the ambience itself is worth a visit.
#   Rating: 4
#   Review Text: Lovely little place. It’s tiny so not many seats but I still managed to get a cozy seat when I went on a Friday afternoon
#
# Friendly and gentle service. You get to collate members’ points. The coffee was good. Sandwich-sandos was nice but a little too normal, something I could likely put together myself. They probably need to make it abit tastier for repeat customers. Brownies were great though, loved the matcha one! together with the ambience and service everything, still a 4/5! Will go back if I’m around the area
#   Rating: 5
#   Review Text: It is a nice coffee cosy place in the Ang Mo Kio heartland. Nice coffee and lots of carpark space. It has 2 outdoor seating, only disadvantage is the limited space for seating.
# ----------------------------------------
# Place ID: ChIJa9-WMuYW2jERpX9iQ7SEmws
# Name: Ah Gu Kaka Wa 国昌川味馆
# Reviews:
#   Rating: 3
#   Review Text: Not a big fan of this cuisine. The BBQ sticks（串烧）is slightly tasteless, and the beef sticks are tough. The appetiser is ok and the chives dumplings are probably the best among the dishes we ordered. The service can be improved as the staff are quite passive in recommending dishes. The next good thing is the location,  quite convenient and accessible (just beware difficulty in parking because of the HDB construction nearby).
#   Rating: 3
#   Review Text: Located at one side of Dickson Mall, Ang Mo Kio .. visible from main road, with a close-by open-air car park.
# They specialise in "frog" dishes, which I did not try, so my 3-Star grading "may" not be fair, my apologies.
# I usually grade Food according to past experiences with almost same type, taste, dish-name, flavour and presentations.
# The Spicy Chicken was normal  with chunks of chicken meat. Flavour was plain.
# To be fair, we ordered another same dish order, recommending that some additional flavour like spice and salt be added - which turned out to be more delicious.
# The Sour Soup Fish Slice dish was above-average - too much vinegar added, making the soup base hard to consume. Fish slices were fresh and taste nice though.
# The cucumber slice dish was above average.
# Had 5 different types of skewered meat - average grade.
# Drinks selection is good, Service Staffs are friendly and helpful.
# Last dish was the marinated meat slices in sauce and condiments - this is a nice, delicious dish.
# As mentioned, I had not tried their specialty dishes ... which I will try on future visits .. and review my opinions after that.
#   Rating: 4
#   Review Text: Peaceful place for a weekday dinner. Pricing is acceptable for an aircon environment and food is average. Service was not bad. Was hoping for some spicy food but Didn’t find the sichuan sliced pork spicy at all. The stir fried 3 vegetables were not bad with the potatoes and eggplant well fried and not overly sweet. Credit card payment available but not Amex.
#   Rating: 4
#   Review Text: Good place to have some nice Chinese BBQ over simple drinks. Also enjoyed their Chilled Tofu with Century Eggs and Fried Eggs with Tomato. The Pork Skewers with Enoki Mushroom were our favourite.
#   Rating: 3
#   Review Text: Been here a few times, sincerely hope they can maintain the food standard. Most of the time  food is good but at times when chef have a bad hair day food can be just so-so only😐
#
# Noticed that they have increased on the food portion 👍👍👍 Salty fish slices for two is more than enough for the small order, cheers!
# ----------------------------------------
# Place ID: ChIJYZ3qqZ8b2jER456-75ycqgw
# Name: Get Some
# Reviews:
#   Rating: 5
#   Review Text: Got some craft beers here, and I was impressed by the service. Burmese lady was welcoming and polite, and suggested that I
# tried some beers before ordering. There were 20 beers on tap, each priced from $8-20++ during Happy Hours (daily till 8pm). Keropok was provided free of charge. Unfortunately, the food here was quite disappointing. Spicy mid wings were well fried but were just normal wings that came with packet chilli sauce. 😅 Raw oysters were bland and not plump. Overall, a nice place to chill over a couple of drinks. I suggest checking out their deals in Eatigo before heading down.
#   Rating: 5
#   Review Text: The food we ordered (sliced cold beef tenderloin, stuffed chicken, lamb rack) were delicious! Particularly the chicken and the lamb, they were amazingly cooked. Worth a next return visit!
#
# We didn’t stay long as the air conditioned area is pretty limited and with a guy speaking rather loudly at the adjacent table, it just made the environment abit inconducive.
#   Rating: 5
#   Review Text: 1st time here. Was served by a young Chinese boy who happens to be the cook.
#
# We had the whisky steak and chicken... Wow it's was really good.
#
# Kudos to the young chef and v good service. Will return again.
#
# Thank u
#   Rating: 1
#   Review Text: To be fair, I did not dine there so 3 stars for service and atmosphere.
#
# Ordered a beef chili nachos for $15.90 to share. It is considered VERY EXPENSIVE for what I got!
#
# The nachos tasted oily and slightly stale, but still can accept it since this is a delivery.
#
# However, the chili was barely a tablespoon for each of the two boxes and very little cheese. Also very oily. Felt like they were just trying to dump the bottom of the chili with all the oil just to make the order.
#
# Whatever oil you see in the container is from that miserly chili and trust me you can count the number of beef mince.
#
# Very, very disappointed.
#   Rating: 5
#   Review Text: Just below the block where I'm staying. Convenient to sneak out for dinner or supper when the little ones is fast asleep. Very spoiled for the  options of beer on the list. Recommendation from the staff fits my liking. Food took longer than expected to serve but the wait was definitely worthwhile! Can see that the chef's passion and effort while carefully layout and garnish the dishes. Awesome! Taste wise, definitely worth my 5 stars. Just that the portion is little bit smaller than my appetite. Perhaps the owner just want us to "Get some" more
# ----------------------------------------
# Onwer and staffs are friendly.
# They are very welcoming.
#
# Ordered Spaghetti with Chicken Cutlet & Spaghetti with Fish Fillet. Total spent: $20.60 because it's takeaway.
#
# Food is delicious but it's a good quantity for my wife but not for me. Haha. Should have ordered additional items.
#
# Highly recommended. I will still come back again for other food menu.
#
# The shop accept paynow, digital payment & cdc vouchers.
#   Rating: 4
#   Review Text: 3.5 stars. Clean and spacious restaurant with simple set up. Ordered chicken chop on hot plate with black pepper sauce, curry chicken with prata and lime juice (forgot to take picture). The dishes were average, not bad. The chicken chop was tender, fries were thick and chunky, the vegetables (carrot and broccoli) were fresh. The serving for the curry was not generous, there was only one small piece of chicken in the curry and a few pieces of potato. The taste is nice, similar to home cooked curry. They have another type of curry on the menu, claypot curry with bread or rice, that is a thicker version of curry. The prata is crispy and tasted nice with the curry. Lime juice has sour plum taste, quite refreshing. The restaurant serves dim sum and many other items such as spring chicken, fried rice, spaghetti, and cheese fries etc., I may return to try other dishes. Service was alright, the staff was quite friendly and efficient.
#   Rating: 5
#   Review Text: Located in the heartland of AMK hdb shophouse, kinda underated to me .. not much of a crowd.
# Very chill ambience, ample parking spaces, and this Western food stall serves affordable western food & some other menus like curry chicken and dim sum. Potion was generous, and the food was not bad compared to some other coffee shop shop. It's halal & open every day
# Enjoying food without any Gst or svc charge is rare these days!! Definitely recommended for a budget friendly eaterie .. 👍🏻👍🏻
#   Rating: 4
#   Review Text: This is a halal cafe which serves western food. The set up is simple and prices are reasonable for the portions. I had the chicken cutlet with pepper sauce on a hot plate. It was served with a good portion of mashed potato which had the sauce in an indentation in the middle. Nice presentation.
# ----------------------------------------
# Place ID: ChIJpaXv6kIb2jERaR2t1KW20sk
# Name: Lazy Lizard - NEWest
# Reviews:
#   Rating: 5
#   Review Text: Very 'at ease' ambience, making it a very enjoyable big family dinner. The pizzas are surprisingly good with the crust being very crispy and thin.
# The kids enjoyed their various selection of food and even remarked they would like to be back again soon!
#   Rating: 5
#   Review Text: We stumble upon the Lazy Lizard after our morning walk at West Coast Park.
# Braised beef cheek is the best that we have eaten. It is soft & tender and the sauce captures the right flavour. Excellent!!
# Fish and chips is very good, batter is thin and crispy, the fries have a crunchy exterior and a light fluffy interior.
# We will be back.
#   Rating: 5
#   Review Text: Love the deco and ambience here. It's football themed and you can even watch football or highlights here. Saints fans would enjoy this place very much.
#
# The food was good and the service was excellent. Very friendly crew on a busy Friday evening.
#   Rating: 5
#   Review Text: Went with my family for a weekend lunch, not a lot of people there but still a decent amount of people for a less populated area in the West.
#
# I ordered the pork rack and it’s a pork chop with bone. The meat was really good and tender!! Paired with the creamy black pepper sauce, it’s so good. But the mushrooms were average and a little weird tasting because it was cooked in wine/balsamic vinegar. The mash was decent.
#
# The pork ribs had 2 ribs, which is a little sad when compared to other places and for it’s price point I think it’s a dish to avoid. You can always easily find better ribs at other pub places.
#
# Fish and chips was good too. Used barramundi fish so it’s better quality and taste than other fish and chips that uses dory.
#
# The pizza was also super good. We ordered the mentaiko seafood pizza. While the dough is nothing special, the toppings were sooo good and extra saucy! It had clams and mini prawns.
#
# It’s definitely a place to return to.
#   Rating: 4
#   Review Text: The food was generally okay, and the service was prompt. I ordered a medium ribeye, but it was overcooked. After informing the service crew, they immediately offered to replace it, and the replacement ribeye was much better. The restaurant provides complimentary soup, dessert, and drinks with the order of a main dish (pizza, pasta, mains, risotto, burger). Overall, it was a pleasant dining experience.
# ----------------------------------------
# Place ID: ChIJRSqmS3wX2jERmuvyhbrAunc
# Name: The Soup Spoon
# Reviews:
#   Rating: 3
#   Review Text: Standard soup spoon outlet, taste is consistent to other outlets. The salad here is pretty good, but portion is quite small and pricey. The good thing is that the location is very convenient in AMK hub, so I would probably come back here due to the close proximity of the restaurant. Overall I’ll give it 3 stars! :)
#   Rating: 2
#   Review Text: Not the best Soup Spoon outlet to begin with but we frequent it fairly often due to proximity to our home.
#
# Please do not use tough croutons for your Caesar Salad, it's so burnt and chewy but when we feedbacked to the staff, he could still say "Oh, we use sourdough bread, so it's like this". May we suggest to the management to not use sourdough bread? Or whatever tough leftover bread simply because nobody eats them? Croutons are supposed to be a crunchy topping, not pieces of leather to train your incisors. I urge the management to fly back to culinary school because this is unacceptable.
#
# The mobile ordering Souperholic app is also damn maddening. The image files for coupons are not easily seen and you got to manually click on it to expand the description. Just ask your developer to do a better job. We did not manage to see the free broccoli side dish and asked the staff if they could add it in our order but the answer was "No, you have to make another order again. "
#
# Despite the poor serving quantity at AMKhub as compared to other outlets, we have been willing consumers because we believe the nutritional quality of their food is kinda better than many of the junk out there, but finally, enough is enough. We do not have to put up with the lacklustre food anymore as this is our last visit to this sub-standard outlet. The aircon at the basement of AMKHUB is also non-existent these days. Not like it's their fault but it just makes deciding easier for us.
#   Rating: 4
#   Review Text: Dining area was pretty empty on a weekday. Ordering through the kiosk was easy. Service crew were patient and quick to clear the used trays of utensils and cutleries.
#
# I realised that my Rosella tea and spinach which I had ordered on the app was not received by the outlet. It was my first time trying out the app and after sending in, an order number came in without me having to make payment. I went to the outlet to clarify and the staff on duty said the the order did not go through. When I checked the app, the items were no longer available for redemption too.
#
# The beef goulash was a tad too sourish and my children did not really fancy the taste. The burger tasted really great.
#   Rating: 5
#   Review Text: taste is consistent with other outlets, so no complaints there. the service staff was super polite and friendly! they were very willing to attend to my slight special requests and served my soup hot! can tell that the management is really good at this outlet as compared to others around SG.
#   Rating: 1
#   Review Text: Look at the old photo in october 2023 and new photo in april 2024
# What the flying fork. Look how much it shrinked. Ggwp
# No more antoheetos
# ----------------------------------------
# Place ID: ChIJtzqFfeUW2jERnMM7mzrcaAc
# Name: Fish & Chicks
# Reviews:
#   Rating: 1
#   Review Text: Get this 1 for 1 promotion from Fish and Chicks @$18.60 on Deliveroo.
# But I'm surprised by the potion.
# Two small pieces of fish, and just 1 spoonful of coleslaw. The potion is small, just like a kid's meal.
# Fries quantity is decent for me.
# As for the chilli crab sauce, it's more like chilli crab oil, though the taste is ok.
# It's my first time trying their food and will be my last.
#   Rating: 2
#   Review Text: Aglio olio is pretty good, except it’s very oily. Portion of fish and chicken kinda little (from half price menu at $13.90). Mentaiko pasta ($13.90) was overcooked and grilled Salmon was dry. It was filling but jelak. Waiting time around 20minutes for two items.
#   Rating: 4
#   Review Text: The signature fish chicken may be a bit expensive but the portion is seriously big! Their fries are nice when freshly fried and I love the chicken cutlet batter! 2 person can share if both are normal portion eaters..
#   Rating: 1
#   Review Text: Very low quality ingredients. Bland bolognese. Gave this stall multiple chances and tried it again and again . However nothing has changed. I do not recommend
#   Rating: 3
#   Review Text: First time trying. The chicken chop is not bad, grilled yet retaining the tenderness of the meat. The fries are not the chunky kind, tasted dry. There is coleslaw too.
# ----------------------------------------
# Place ID: ChIJtcueEmMX2jERDd0F1MIp2x8
# Name: ANDES by ASTONS @ SAFRA Toa Payoh
# Reviews:
#   Rating: 4
#   Review Text: ANDES by ASTONS @ SAFRA Toa Payoh, a halal-certified and MUIS-accredited restaurant in Singapore, caters to those in search of delicious and affordable steaks and Western cuisine, particularly Muslim diners. Being an extension of ASTONS Specialties, it prides itself on offering a menu crafted from high-quality, fresh ingredients. While the restaurant has garnered a mix of positive and negative feedback, with some patrons lauding the value-for-money offerings, others have differing opinions. With an overall rating of 3.5 out of 5 stars on platforms like Tripadvisor from 44 reviews, the restaurant presents varying experiences to its customers.
#
# During my visit, I encountered issues with the service staff's slow efficiency and forgetfulness of orders, leading to repeated requests. To enhance the dining experience, I suggest implementing QR code ordering, a popular trend in many restaurants today. Additionally, there was a mix-up with my side dish, resulting in the wrong item being served initially. However, upon notifying the staff, they promptly rectified the mistake by providing the correct side dish in a separate bowl. Despite these hiccups, the food maintained its delicious taste and remained value for money.
#
# Overall, I believe ANDES by ASTONS @ SAFRA Toa Payoh deserves a 4-star rating, considering their swift action to rectify errors and the overall quality of the dining experience. Implementing QR code ordering could streamline the process for both customers and staff, further enhancing the dining experience for all patrons.
#   Rating: 2
#   Review Text: Food is not nice, the carbonara and the fish were dry and hard. Food presentation really messy. Service is just drop food on the table. The restaurant is however suitable for families with children.
#   Rating: 1
#   Review Text: Ordered their porterhouse steak, asked for a medium.
#
# Look at this.
# Dry as hell, worse than jerky.
#
# Don’t open a western food shop if you can barely cook a steak.
#
# What a disgrace.
#
# Service staff we’re nice and attentive though
#   Rating: 4
#   Review Text: Much needed refill after a gym session. The food was nice in a balanced proportion. Service was great in a wonderful ambience.
#   Rating: 3
#   Review Text: My team chose this place for cohesion lunch and we had to preorder our food due to the size of our group.
#
# I was initially going for my usual ieat Super burger then changed my mind to try their steak and crispy fried chicken instead.
#
# Was disappointed I had to say...steak was tough and stringy and crispy chicken was no where near my expectations.
#
# Observed the other dishes were also not that spectacular and there were more than a few of my group who left food u eaten...not a good sign.
#
# Which brings to me to query why the restaurant is crowded... especially given it's a weekday.
# ----------------------------------------
# Place ID: ChIJOaGYeW4X2jERfxs9g4eb7KI
# Name: Toa Payoh Lorong 8 Market & Hawker Centre
#
# Chicken Green Curry
#
# tender chicken simmered in a flavorful green curry sauce. Infused with aromatic herbs like lemongrass, kaffir lime leaves, and green chili peppers, the curry achieves a perfect blend of spiciness and creaminess, thanks to the inclusion of coconut milk. This visually appealing dish, served with jasmine rice, delivers a satisfying balance of vibrant flavors in every bite.
#
# …
#
# Chicken Omelette
#
# The eggs envelop the chicken, often combined with vegetables or herbs, resulting in a satisfying and quick culinary delight.
#
# …
#
# Stir Fry Kang Kong Thai Style
#
# The vibrant greens are tossed in a savory sauce, creating a zesty and aromatic side dish or main course. The result is a delightful combination of crisp kang kong, bold Thai flavors, and a touch of heat, making it a popular and satisfying choice in Thai cuisine.
#
# …
#
# Pineapple Fried Rice
#
# It  is a colorful and aromatic fried rice with a delightful balance of sweet and savory notes, offering a tropical twist to this classic Asian dish.
#
# …
#
# Thai Style Fried Chicken Cutlet
#
# This Thai twist on fried chicken offers a delightful combination of crunchy texture and bold, savory flavors, making it a popular and satisfying dish in Thai cuisine.
#
# …
#
# Lamb Chop
#
# The rich taste of lamb is complemented by a variety of seasoning options, rosemary, thyme, and other herbs. Lamb chops are popular for their juicy and robust flavor, making them a favorite choice for meat enthusiasts seeking a hearty and satisfying dining experience.
#
# …
#
# Thai Iced Milk Tea
#
# It is a creamy, sweet, and aromatic iced tea, served over ice cubes, providing a refreshing and indulgent treat.
#
# …
#
# Thai Iced Lemongrass
#
# It is a cool and invigorating beverage with a distinctive lemongrass aroma and a subtle sweetness.
#
# …
#
# Thai Iced Lemon Tea
#
# A harmonious blend of robust tea, citrusy notes, and a touch of sweetness.
#
# @arizesg
#
# 293 Lor 6 Toa Payoh, #03-03, Singapore 319387
# .
# .
#
# .
# .
# #issacfoodie #issacfriends
# ----------------------------------------
# Place ID: ChIJT2GBZo8a2jERu9mn5OEBi1o
# Name: Ban Tong Seafood
# Reviews:
#   Rating: 1
#   Review Text: Food was not fresh, we had indigestion and nausea after eating here.
#
# We ordered the hotplate tofu, pork ribs, cereal prawn, sambal sweet potato leaves, and long beans. Tastewise, the food was mediocre. The cereal prawn had very thick batter, making it difficult to eat.
#
# Will not be returning as the food is not fresh.
#   Rating: 5
#   Review Text: Good zichar in Kopitiam at Clementi Ave 5. Expect long queues in the evening.
#
# Wanted to order their silver fish fried rice (bait fish) but they didn’t have it so I ended up with their Seafood Hor Fun. Definitely got wok heat in the hor fun noodles which was slightly chewy. In the plate were prawns, sliced pork and fish. Quite standard and portion was decent for a small portion $5. Nice.
#   Rating: 5
#   Review Text: Lady boss is friendly and hospitable. Food was delicious and my parents, usually food picky, enjoyed the food as well. Recommended dishes include the mushrooms trotters and claypot fish
#   Rating: 5
#   Review Text: It was a huge crowd on a Sunday! Luckily we came at 5pm. My second visit here. Lady boss is very friendly over the phone and will help to pre-order seafood. She also provide good recommendations on choice of sauces for the seafood.
#
# The cereal crayfish is most popular and we finished every single morsel of the cereal! Coming a close second is the signature box chicken is like deep fried chix slices with Kung Pao sauce. Best paired with beer !!!
#
# Though the braised pork knuckles is only avail in a single size, don’t be daunted by its price. It’s quite a big portion with mushrooms and peanuts as accompaniments. We couldn’t finish and took the rest home for supper !
#
# The female boss also kept half a fresh red snapper for us and it had firm flesh. We went with Teochew steam style with generous condiments on the side.
#
# Skip the prawn roll as it is average. The sambal Kang kong is slightly spicy and you can request for less oil.
#   Rating: 5
#   Review Text: Food is fantastic. Super love their cereal clayfish. 排骨王 is very good. Very good zi char olace at Clementi. Worth to go visiting.
# ----------------------------------------
# Place ID: ChIJ07REv-cW2jERcip7FWd9Oqk
# Name: Xi Xiang Feng Yong Tau Foo 喜相逢
# Reviews:
#   Rating: 5
#   Review Text: Verified again on Aug ‘24. Soup is the real deal. Seller mentioned home made minced meat fish cake.
#
# Last time review.
# The soup is the reason i come for. Every ship with beans full of protein. Soup is sweet because there is pork meat and ikan bilis.
#
# I think they made their own fish cake with minced pork. That’s nice. Tau fu big piece.
#
# Chilli sauce taste unique, has a toasted aroma, i guess it’s toasted sesame.
#   Rating: 2
#   Review Text: Very salty but portion is big .. super long queue.take 40 mins to wait . Not worth the waiting .. super msg n salt in the food and soup.. good is soup added plenty of bean. Will not visit the store again..
#   Rating: 3
#   Review Text: April 2024: have been wanting to try this stall for ages and finally had an opportunity to do so as I saw that the queue was manageable. Little did I know that some of those in the front of the queue ordered multiple bowls! Also, as I observed, the queue is long as the cook was slow. Yes the food was good but for the time wasted standing in queue and having the rest of the family just waiting for me, I’d rather not visit this stall again. Time better spent elsewhere. Lastly, they don’t have kway teow. Only bee Hoon, yellow noodles and Chee Cheong fun.
#   Rating: 4
#   Review Text: One of the popular stalls which always have people queuing. Choose your ingredients before joining the queue. Their items are fresh & chunky.
#   Rating: 4
#   Review Text: The sweet sauce and chilli goes well together. But if you can’t take spicy, remember to ask the aunty not to add. The sweet sauce is good enough too. Fried items were fried again so is hot and crispy. The soup is tasty too. Remember to choose your selections first if there’s a long queue.
# ----------------------------------------
# Place ID: ChIJ6fH-zI8a2jERqFn_sqy5xOk
# Name: Crystal Jade Hong Kong Kitchen
# Reviews:
#   Rating: 4
#   Review Text: This is a newly opened Hong Kong cuisine chain restaurant. We came here on a public holiday & had to queue for 15 min. Dim sum quality was quite ok except for the congee which was too gluey. The item that stood out was the Malai Gao, served steaming hot with fragrant buttery caramel aroma & a really fluffy texture.
#   Rating: 4
#   Review Text: Not crowded for lunch during the weekdays. Dim sum was still good as before. Service was prompt. Deep fried mango could be more juicer, felt abit dry for the mango part.
#   Rating: 4
#   Review Text: This is a smaller location compared to others but we were able to get a table nearer to the windows and away from the mall foot traffic.
#
# They take reservation online but because it's a weekday, it wasn't crowded. I do appreciate a text message reminder closer to my reservation.
#
# We ordered a varied selection of dim sum dishes and half a Peking duck with kai lan for a very satisfying lunch between four people. The duck was served two ways; crunchy skin with wrap and the meat sliced up.
#
# The service was prompt with food being served and table cleared efficiently. The staff was also very good at refilling our tea throughout our time there.
#   Review Text: Excellent Sichuan food, albeit a bit salty for my taste. Portions are generous and service is great.
# ----------------------------------------
# Place ID: ChIJOcLdGoka2jERyBKbpZDUWDo
# Name: Dajie Makan Place
# Reviews:
#   Rating: 5
#   Review Text: Me and my friend tried Mala level 2 and the Hakka Yong Tau Foo. It was amazing!! Love the clean and neat packing of the ingredients and most of the food in the fridge drawer was well maintained as well!  The staff were all friendly too! I decided on what to eat thanks to other patrons who were happy to share what's good there! Definitely will come back to try others!
#   Rating: 5
#   Review Text: Was looking for something comforting on a wet sunday evening, and we stumbled upon this place.
#
# Located in a quiet neighborhood, this place is quite accessible if you drive,there are buses too that pass near the area.
#
# When we got there it was during dinner but luckily for us the place was quite empty other than 2 other couple.
#
# There is definitely a range of items to choose from, such as meat, seafood ,etc, so you'll have enough choices to put in your bowls.
#
# We managed to order the mala hot pot. 10 items and a drink total was about $12+. It was really decent for 2 people. It came with 2 bowls of soups as well.
#
# Of course we had to choose the lowest level of spiciness and thankful when the food came, the spiciness level was just nice for the both of us. The soup complemented the dish to sooth the spiciness.
#
# It was definitely a good and comforting meal. I, too, realized they have many other outlets, and there's 1 at yishun. It looks like I'll be visiting there more often.
#   Rating: 5
#   Review Text: Took abt 5 items (noodle, seaweed, beancurd skin, veg, mushroom) and several pieces of lotus root and two slices of potato. Had it in laska and with a drink $8.20.
#   Rating: 5
#   Review Text: Came on Friday for lunch, had a small crowd.
# Food was great, appreciate the soup provided with the Mala hotpot. Love the iced milk tea, just nice to kill the spiciness of the Mala.
#   Rating: 5
#   Review Text: Not crowded with people during Sat lunchtime, no flies, even thought outdoors, not hot. Food is Halal for Mala! Taste good, my Muslim friend enjoyed together with me. They also have other dishes such as fried rice, chicken rice available. Chicken meat is tender. Overall, happy experience with my friends there to catch up and eat slowly together.
# ----------------------------------------

# %% [markdown]
# ---
#
# ### **2. Limitations of Google Maps Places API for Review Retrieval**
#
# **Limited Number of Reviews:**
#
# The Google Places API only allows you to retrieve up to 5 reviews per place, even if there are many more reviews available on Google Maps. This can be a significant limitation if you're trying to gather comprehensive feedback on a location, as you'll miss out on a large portion of the user opinions that could provide valuable insights.
#
# **Only Recent Reviews, No Historical Data:**
#
# Another limitation is that the API only provides the most recent reviews. If you're interested in seeing how the perception of a place has changed over time or if you want to analyze older reviews, the API won't be helpful. It doesn’t offer access to a place's full review history, so you’re stuck with just the latest few opinions.
#
# ### **Avoiding the Limitation**
#
# **Use Web Scraping (With Caution):**
#
# To get around the limitation of only retrieving 5 reviews, one alternative is web scraping, which involves programmatically extracting data directly from the Google Maps website instead of using the API. This method could allow you to access all available reviews, not just the most recent five.
#
# However, it's important to note that web scraping is not officially supported by Google and can be against their terms of service. This means that if Google detects that you are scraping their site, they could block your IP address, or worse, take legal action. Additionally, scraping often involves complex code and can be affected by changes in the website’s structure. Because of these risks, it's essential to consider the ethical and legal implications carefully before deciding to use web scraping. For academic purposes or legitimate data analysis, it’s better to explore other methods or to seek permission from Google.
